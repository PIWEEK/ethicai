# %% [markdown]
# Spaceship Titanic
# =================
#
# https://www.kaggle.com/competitions/spaceship-titanic/code?competitionId=34377

# %%
import pandas as pd
import joblib

import warnings
warnings.filterwarnings('ignore')

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

import Spaceship_Titanic_data
# Out:
# (train) Number of rows = 8693 and Number of cols = 14
# (test) Number of rows = 4277 and Number of cols = 13

# %% [markdown]
# Create and train a model
# ------------------------

# %% [markdown]
# Create a model with the processing pipeline and one classifier.

# %%
model = Pipeline(
    [
        ('preproc', Spaceship_Titanic_data.preproc),
        ('drop_target', Spaceship_Titanic_data.drop_target),
        ('cla', LogisticRegression())
    ]
).set_output(transform='pandas')

# %% [markdown]
# Create a `GridSearchCV` to try many variants of the model, with different strategies and parameters, and find the combination with the best score.

# %%
param_grid = [
    {
        'preproc__imputer__num_imputer__strategy': ['mean', 'median'],
        'preproc__scale_encode__minmax_scaler__feature_range': [(0, 1), (-1, 1)],
        'cla': (LogisticRegression(),),
        'cla__C': [0.5, 1.0, 5.0],
        'cla__max_iter': [1000],
        'cla__class_weight': [None, 'balanced']
    },
    {
        'preproc__imputer__num_imputer__strategy': ['mean', 'median'],
        'preproc__scale_encode__minmax_scaler__feature_range': [(0, 1), (-1, 1)],
        'cla': (KNeighborsClassifier(),),
        'cla__n_neighbors': [3, 5, 7],
        'cla__weights': ['uniform', 'distance']
    },
    {
        'preproc__imputer__num_imputer__strategy': ['mean', 'median'],
        'preproc__scale_encode__minmax_scaler__feature_range': [(0, 1), (-1, 1)],
        'cla': (MLPClassifier(),),
        'cla__hidden_layer_sizes': [(20,), (25,), (30,)],
        'cla__activation': ['logistic', 'relu'],
        'cla__max_iter': [1500]
    },
    {
        'preproc__imputer__num_imputer__strategy': ['mean', 'median'],
        'preproc__scale_encode__minmax_scaler__feature_range': [(0, 1), (-1, 1)],
        'cla': (DecisionTreeClassifier(),),
        'cla__criterion': ['gini', 'entropy'],
        'cla__max_depth': [5, 8, 10]
    },
    {
        'preproc__imputer__num_imputer__strategy': ['mean', 'median'],
        'preproc__scale_encode__minmax_scaler__feature_range': [(0, 1), (-1, 1)],
        'cla': (RandomForestClassifier(),),
        'cla__n_estimators': [50, 100, 150],
        'cla__max_depth': [5, 8, 10]
    }
]   

gs = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='roc_auc',
    error_score='raise',
    cv=5,
    verbose=1,  # Set to 10 to print traces and know the % progress (very verbose)
    n_jobs=-1   # -1 uses all CPU cores; you can give a number > 0 to use that number of cores
)

# %% [markdown]
# Fit all variants and display the scores.

# %%
gs.fit(Spaceship_Titanic_data.train_data,
       Spaceship_Titanic_data.train_data.Transported)

result = pd.DataFrame(gs.cv_results_).sort_values(by='rank_test_score').reset_index(drop=True)

result
# Out:
# Fitting 5 folds for each of 132 candidates, totalling 660 fits
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         6.771168      1.171175         0.054181        0.011710
# 1         6.194542      1.349712         0.059627        0.015667
# 2         9.307644      0.938977         0.043057        0.001795
# 3         6.599462      1.868093         0.060165        0.020765
# 4        10.219923      1.365393         0.045205        0.001667
# ..             ...           ...              ...             ...
# 127       0.167929      0.058305         0.053930        0.018985
# 128       0.144176      0.013922         0.054543        0.024999
# 129       0.153028      0.015440         0.041838        0.003846
# 130       0.162532      0.026810         0.044388        0.003968
# 131       0.152752      0.020786         0.051640        0.014785
#
#                                              param_cla param_cla__C  \
# 0    MLPClassifier(hidden_layer_sizes=(25,), max_it...          NaN
# 1    MLPClassifier(hidden_layer_sizes=(25,), max_it...          NaN
# 2    MLPClassifier(hidden_layer_sizes=(25,), max_it...          NaN
# 3    MLPClassifier(hidden_layer_sizes=(25,), max_it...          NaN
# 4    MLPClassifier(hidden_layer_sizes=(25,), max_it...          NaN
# ..                                                 ...          ...
# 127                           DecisionTreeClassifier()          NaN
# 128                           DecisionTreeClassifier()          NaN
# 129                           DecisionTreeClassifier()          NaN
# 130                           DecisionTreeClassifier()          NaN
# 131                           DecisionTreeClassifier()          NaN
#
#     param_cla__class_weight param_cla__max_iter  \
# 0                       NaN                1500
# 1                       NaN                1500
# 2                       NaN                1500
# 3                       NaN                1500
# 4                       NaN                1500
# ..                      ...                 ...
# 127                     NaN                 NaN
# 128                     NaN                 NaN
# 129                     NaN                 NaN
# 130                     NaN                 NaN
# 131                     NaN                 NaN
#
#     param_preproc__imputer__num_imputer__strategy  \
# 0                                            mean
# 1                                            mean
# 2                                          median
# 3                                          median
# 4                                          median
# ..                                            ...
# 127                                          mean
# 128                                        median
# 129                                        median
# 130                                          mean
# 131                                          mean
#
#     param_preproc__scale_encode__minmax_scaler__feature_range  ...  \
# 0                                              (-1, 1)         ...
# 1                                              (-1, 1)         ...
# 2                                               (0, 1)         ...
# 3                                              (-1, 1)         ...
# 4                                               (0, 1)         ...
# ..                                                 ...         ...
# 127                                             (0, 1)         ...
# 128                                             (0, 1)         ...
# 129                                            (-1, 1)         ...
# 130                                             (0, 1)         ...
# 131                                            (-1, 1)         ...
#
#     param_cla__n_estimators  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 127                     NaN
# 128                     NaN
# 129                     NaN
# 130                     NaN
# 131                     NaN
#
#                                                 params split0_test_score  \
# 0    {'cla': MLPClassifier(hidden_layer_sizes=(25,)...          0.876891
# 1    {'cla': MLPClassifier(hidden_layer_sizes=(25,)...          0.876465
# 2    {'cla': MLPClassifier(hidden_layer_sizes=(25,)...          0.879648
# 3    {'cla': MLPClassifier(hidden_layer_sizes=(25,)...          0.870675
# 4    {'cla': MLPClassifier(hidden_layer_sizes=(25,)...          0.878566
# ..                                                 ...               ...
# 127  {'cla': DecisionTreeClassifier(), 'cla__criter...          0.341983
# 128  {'cla': DecisionTreeClassifier(), 'cla__criter...          0.385767
# 129  {'cla': DecisionTreeClassifier(), 'cla__criter...          0.383105
# 130  {'cla': DecisionTreeClassifier(), 'cla__criter...          0.350918
# 131  {'cla': DecisionTreeClassifier(), 'cla__criter...          0.350385
#
#     split1_test_score split2_test_score split3_test_score split4_test_score  \
# 0            0.876379          0.873895          0.884220          0.887344
# 1            0.879384          0.872711          0.881952          0.887468
# 2            0.873247          0.872034          0.878514          0.893754
# 3            0.879425          0.876958          0.879827          0.889973
# 4            0.873286          0.872421          0.878114          0.892982
# ..                ...               ...               ...               ...
# 127          0.703208          0.733690          0.842233          0.641190
# 128          0.654293          0.731162          0.837144          0.608891
# 129          0.651302          0.729035          0.836746          0.609778
# 130          0.646818          0.724119          0.817722          0.601386
# 131          0.644670          0.724626          0.817722          0.602089
#
#     mean_test_score  std_test_score  rank_test_score
# 0          0.879746        0.005128                1
# 1          0.879596        0.004995                2
# 2          0.879439        0.007733                3
# 3          0.879372        0.006230                4
# 4          0.879074        0.007381                5
# ..              ...             ...              ...
# 127        0.652461        0.168351              128
# 128        0.643452        0.150282              129
# 129        0.641993        0.150766              130
# 130        0.628193        0.156888              131
# 131        0.627899        0.157067              132
#
# [132 rows x 26 columns]

# %% [markdown]
# Choose the optimal model

# %%
optimal_model = gs.best_estimator_

optimal_model
# Out:
# Pipeline(steps=[('preproc',
#                  Pipeline(steps=[('fe_eng',
#                                   FunctionTransformer(func=<function feature_engineering at 0x7fc3b7eb97e0>)),
#                                  ('imputer',
#                                   ColumnTransformer(remainder='passthrough',
#                                                     transformers=[('label_imputer',
#                                                                    SimpleImputer(strategy='most_frequent'),
#                                                                    ['HomePlanet',
#                                                                     'CryoSleep',
#                                                                     'Destination',
#                                                                     'VIP',
#                                                                     'PassengerGGG',
#                                                                     'PassengerPP']),
#                                                                   ('num_imputer',
#                                                                    SimpleIm...
#                                                                    MinMaxScaler(feature_range=(-1,
#                                                                                                1)),
#                                                                    ['PassengerGGG',
#                                                                     'PassengerPP']),
#                                                                   ('one_hot',
#                                                                    OneHotEncoder(handle_unknown='infrequent_if_exist',
#                                                                                  sparse_output=False),
#                                                                    ['HomePlanet',
#                                                                     'CryoSleep',
#                                                                     'Destination',
#                                                                     'VIP'])],
#                                                     verbose_feature_names_out=False))])),
#                 ('drop_target',
#                  FunctionTransformer(func=<function drp_trg at 0x7fc3b7f06950>)),
#                 ('cla',
#                  MLPClassifier(hidden_layer_sizes=(25,), max_iter=1500))])

# %% [markdown]
# Save the optimal model
# ----------------------

# %%
with open('model.jlb', 'wb') as file:
    joblib.dump(optimal_model, file)

# %% [markdown]
# Use the model to predict the test data
# ----------------------------------

# %%
processor = optimal_model.steps[0][1]
drop_target = optimal_model.steps[1][1]
classifier = optimal_model.steps[2][1]

# This call is necessary for the predict to work. For an unknown reason, if we don't do this, the model expects that
# the data has a 'Transported' column, and fails if not.
dummy = classifier.predict(drop_target.fit_transform(processor.fit_transform(Spaceship_Titanic_data.test_data)))

# %%
prediction = optimal_model.predict(Spaceship_Titanic_data.test_data)

# %% [markdown]
# Generate the output file as required by the Kaggle competition

# %%
output = pd.DataFrame({'PassengerId': Spaceship_Titanic_data.test_data['PassengerId'],
                       'Transported': prediction})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# Output the result including passenger names

# %%
pd.DataFrame({'PassengerId': Spaceship_Titanic_data.test_data['PassengerId'],
              'Name': Spaceship_Titanic_data.test_data['Name'],
              'Transported': prediction})
# Out:
#      PassengerId              Name  Transported
# 0        0013_01   Nelly Carsoning        False
# 1        0018_01    Lerome Peckers        False
# 2        0019_01   Sabih Unhearfus         True
# 3        0021_01  Meratz Caltilter         True
# 4        0023_01   Brence Harperez        False
# ...          ...               ...          ...
# 4272     9266_02       Jeron Peter         True
# 4273     9269_01     Matty Scheron        False
# 4274     9271_01       Jayrin Pore         True
# 4275     9273_01    Kitakan Conale         True
# 4276     9277_01  Lilace Leonzaley         True
#
# [4277 rows x 3 columns]
